# %%
import pandas as pd
df=pd.read_csv('score.csv')

# %%
import pandas as pd
df=pd.read_csv('score.csv')
print(df)
# Out:
#     MathScore  Reading_Score  Reading_Score.1  Placement_Score  Club_Join_Date
# 0          74             89               63               92            2020
# 1          75             94               64               75            2018
# 2          74             94               60               78            2018
# 3          78             84               65               77            2020
# 4          74             87               79               92            2019
# 5          78             87               74               76            2018
# 6          66             94               67               86            2018
# 7          64             92               70               89            2021
# 8          69             94               62               86            2018
# 9          64             77               68               90            2019
# 10         69             89               70               98            2019
# ...

# %%
df.isnull()
# Out:
#     MathScore  Reading_Score  Reading_Score.1  Placement_Score  Club_Join_Date
# 0       False          False            False            False           False
# 1       False          False            False            False           False
# 2       False          False            False            False           False
# 3       False          False            False            False           False
# 4       False          False            False            False           False
# 5       False          False            False            False           False
# 6       False          False            False            False           False
# 7       False          False            False            False           False
# 8       False          False            False            False           False
# 9       False          False            False            False           False
# 10      False          False            False            False           False
# ...

# %%
series=pd.isnull(df["MathScore"])
df[series]
# Out:
# Empty DataFrame
# Columns: [MathScore, Reading_Score, Reading_Score.1, Placement_Score, Club_Join_Date]
# Index: []

# %%
series=pd.isnull(df["MathScore"])
df[series]
# Out:
# Empty DataFrame
# Columns: [MathScore, Reading_Score, Reading_Score.1, Placement_Score, Club_Join_Date]
# Index: []

# %%
df.isnull()
# Out:
#     MathScore  Reading_Score  Reading_Score.1  Placement_Score  Club_Join_Date
# 0       False          False            False            False           False
# 1       False          False            False            False           False
# 2       False          False            False            False           False
# 3       False          False            False            False           False
# 4       False          False            False            False           False
# 5       False          False            False            False           False
# 6       False          False            False            False           False
# 7       False          False            False            False           False
# 8       False          False            False            False           False
# 9       False          False            False            False           False
# 10      False          False            False            False           False
# ...

# %%
import pandas as pd
df=pd.read_csv('score.csv')
df
# Out:
#     MathScore  Reading_Score  Reading_Score.1  Placement_Score  Club_Join_Date
# 0         NaN             87               61               83            2020
# 1        72.0             76               72               91            2020
# 2        63.0             83               75               77            2018
# 3        60.0             86               63               97            2020
# 4        65.0             85               62               98            2019
# 5        79.0             86               69               98            2018
# 6        70.0             79               71               75            2020
# 7        63.0             80               72               79            2020
# 8        79.0             82               70               99            2018
# 9        65.0             94               63               80            2021
# 10       61.0             77               70               78            2019
# ...

# %%
df.isnull()
# Out:
#     MathScore  Reading_Score  Reading_Score.1  Placement_Score  Club_Join_Date
# 0        True          False            False            False           False
# 1       False          False            False            False           False
# 2       False          False            False            False           False
# 3       False          False            False            False           False
# 4       False          False            False            False           False
# 5       False          False            False            False           False
# 6       False          False            False            False           False
# 7       False          False            False            False           False
# 8       False          False            False            False           False
# 9       False          False            False            False           False
# 10      False          False            False            False           False
# ...

# %%
series=pd.isnull(df["MathScore"])
df[series]
# Out:
#    MathScore  Reading_Score  Reading_Score.1  Placement_Score  Club_Join_Date
# 0        NaN             87               61               83            2020

# %%
import pandas as pd
df=pd.read_csv('score.csv')
df
# Out:
#     MathScore  Reading_Score  Reading_Score.1  Placement_Score  \
# 0         NaN             83               62               87
# 1        71.0             82               67               91
# 2        68.0             77               63               79
# 3        61.0             80               60               80
# 4        74.0             77               71               96
# 5        74.0             86               76               85
# 6        66.0             89               60               80
# 7        76.0             76               71               96
# 8        71.0             80               79               91
# 9        77.0             95               79               91
# 10       79.0             75               80               91
# 11       61.0             77               60               88
# 12       75.0             81               63               91
# 13       64.0             84               63               79
# ...

# %%
m_v=df['math score'].mean()
df['math score'].fillna(value=m_v, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 m_v=df['math score'].mean()
# ...

# %%
math_score_mean = df.get('math score', pd.Series()).mean()


if not math_score_mean.isna():
    df['math score'].fillna(value=math_score_mean, inplace=True)
else:
    print("'math score' column is missing.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 4
#       1 math_score_mean = df.get('math score', pd.Series()).mean()
# ----> 4 if not math_score_mean.isna():
#       5     df['math score'].fillna(value=math_score_mean, inplace=True)
#       6 else:
#
# AttributeError: 'float' object has no attribute 'isna'
